# %%
conda install libhdfs3
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install hdfs3
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from hdfs3 import HDFileSystem
hdfs=HDFileSystem(host='manager.novalocal',port=8020)

# %%
hdfs.ls('/test1_mmingalov')
# Out:
# ['/test1_mmingalov/resolv.conf', '/test1_mmingalov/test2_mmingalov']

# %%
#!cp /etc/resolv.conf /test1_mmingalov/test2_mmingalov/

# %%
hdfs.put('/tmp/local-file.txt', '/test1_mmingalov/test2_mmingalov/local-file.txt')

# %%
with hdfs.open('/test1_mmingalov/test2_mmingalov/local-file.txt') as f:
    data = f.read(1000000)

# %%
print(data)
# Out:
# b'; Created by cloud-init on instance boot automatically, do not edit.\n;\n# Generated by NetworkManager\nnameserver 10.0.2.3\nnameserver 8.8.8.8\nnameserver 8.8.4.4\nsearch localdomain\n'
